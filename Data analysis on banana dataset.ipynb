# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd
file_path=r"C:\Users\ADMIN\OneDrive\Documents\all updates on data analysis sql excel\Bananas Sales.xlsx"
df=pd.read_excel(file_path)
df.head()
# Out:
#    Customer ID Subscription Type  Contract Length (Months)  \
# 0       100001             Basic                       NaN
# 1       100001             Basic                       NaN
# 2       100001             Basic                       NaN
# 3       100001             Basic                       NaN
# 4       100001             Basic                       NaN
#
#   Current Contract Start Current Contract End  Licenses Bought  \
# 0                    NaT                  NaT                0
# 1                    NaT                  NaT                0
# 2                    NaT                  NaT                0
# 3                    NaT                  NaT                0
# 4                    NaT                  NaT                0
#
#    Number of Users Account Creation Month Last Active  Months Active  \
# 0               12             2019-07-01  2020-03-01              8
# 1               11             2019-07-01  2020-03-01              8
# ...

# %%
a=df[['Customer ID','Subscription Type','Months Active']]
print(a)
# Out:
#       Customer ID Subscription Type  Months Active
# 0          100001             Basic              8
# 1          100001             Basic              8
# 2          100001             Basic              8
# 3          100001             Basic              8
# 4          100001             Basic              8
# ...           ...               ...            ...
# 2215       100387             Basic              1
# 2216       100388             Basic              1
# 2217       100389             Basic              1
# 2218       100390             Basic              1
# 2219       100391             Basic              1
#
# [2220 rows x 3 columns]

# %%
a.head(5)
# Out:
#    Customer ID Subscription Type  Months Active
# 0       100001             Basic              8
# 1       100001             Basic              8
# 2       100001             Basic              8
# 3       100001             Basic              8
# 4       100001             Basic              8

# %%
df.dropna(axis=1, inplace=True)

# %%
df.head()
# Out:
#    Customer ID Subscription Type  Licenses Bought  Number of Users  \
# 0       100001             Basic                0               12
# 1       100001             Basic                0               11
# 2       100001             Basic                0               11
# 3       100001             Basic                0                9
# 4       100001             Basic                0               11
#
#   Account Creation Month Last Active  Months Active  Months Since Last Active  \
# 0             2019-07-01  2020-03-01              8                        15
# 1             2019-07-01  2020-03-01              8                        15
# 2             2019-07-01  2020-03-01              8                        15
# 3             2019-07-01  2020-03-01              8                        15
# 4             2019-07-01  2020-03-01              8                        15
#
#   Sales Month  Sales Amount
# 0  2019-07-01             0
# 1  2019-08-01             0
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Subscription Type, Licenses Bought, Number of Users, Account Creation Month, Last Active, Months Active, Months Since Last Active, Sales Month, Sales Amount]
# Index: []

# %%
import seaborn as sns
import matplotlib as plt

# %%
a=sns.barplot(x='Customer ID',y='Number of Users', data=df)
print(a)
# Out:
# Axes(0.125,0.11;0.775x0.77)
