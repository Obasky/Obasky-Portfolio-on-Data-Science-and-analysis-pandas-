# %%
import pandas as pd

# %%
customers=pd.read_csv(r"C:\Users\ADMIN\Downloads\customers-10000.csv")

# %%
first_five= customers.head(5)

# %%
first_five.dropna()
# Out:
#    Index      Customer Id First Name  Last Name                   Company  \
# 0      1  EB54EF1154C3A78    Heather   Callahan              Mosley-David
# 1      2  10dAcafEBbA5FcA   Kristina    Ferrell  Horn, Shepard and Watson
# 2      3  67DAB15Ebe4BE4a     Briana   Andersen               Irwin-Oneal
# 3      4  6d350C5E5eDB4EE      Patty      Ponce          Richardson Group
# 4      5  5820deAdCF23EFe   Kathleen  Mccormick              Carson-Burch
#
#                City                   Country                Phone 1  \
# 0  Lake Jeffborough                    Norway           043-797-5229
# 1        Aaronville                   Andorra           932-062-1802
# 2       East Jordan                     Nepal             8352752061
# 3  East Kristintown  Northern Mariana Islands           302.398.3833
# 4       Andresmouth                     Macao  001-184-153-9683x1497
#
#               Phone 2                             Email Subscription Date  \
# ...

# %%
main= customers[['First Name', 'Last Name']]

# %%
one_main=main.head(100)

# %%
ok=print(one_main['First Name'].str.startswith('s'))
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: First Name, Length: 100, dtype: bool

# %%
print(ok)
# Out:
# None

# %%
q=customers['Subscription Date']

# %%
updated_q=pd.to_datetime(q)

# %%
listed_years=customers['Year']=updated_q.dt.year

# %%
customers['updated_year']= listed_years
customers['updated_year']
# Out:
# 0       2020
# 1       2020
# 2       2022
# 3       2020
# 4       2021
#         ...
# 9995    2022
# 9996    2022
# 9997    2022
# 9998    2020
# 9999    2020
# Name: updated_year, Length: 10000, dtype: int32

# %%
customers.head(5)
# Out:
#    Index      Customer Id First Name  Last Name                   Company  \
# 0      1  EB54EF1154C3A78    Heather   Callahan              Mosley-David
# 1      2  10dAcafEBbA5FcA   Kristina    Ferrell  Horn, Shepard and Watson
# 2      3  67DAB15Ebe4BE4a     Briana   Andersen               Irwin-Oneal
# 3      4  6d350C5E5eDB4EE      Patty      Ponce          Richardson Group
# 4      5  5820deAdCF23EFe   Kathleen  Mccormick              Carson-Burch
#
#                City                   Country                Phone 1  \
# 0  Lake Jeffborough                    Norway           043-797-5229
# 1        Aaronville                   Andorra           932-062-1802
# 2       East Jordan                     Nepal             8352752061
# 3  East Kristintown  Northern Mariana Islands           302.398.3833
# 4       Andresmouth                     Macao  001-184-153-9683x1497
#
#               Phone 2                             Email Subscription Date  \
# ...

# %%
email_sorted=customers['Domain'] = customers['Email'].str.split('@').str[1]

# %%
print(email_sorted)
# Out:
# 0       espinoza-francis.net
# 1           hall-donovan.com
# 2         blevins-sexton.com
# 3                anthony.com
# 4         rangel-shields.com
#                 ...
# 9995              bates.info
# 9996                wade.com
# 9997      barnett-dorsey.com
# 9998     villegas-wilcox.com
# 9999            martinez.com
# Name: Email, Length: 10000, dtype: object

# %%
print(customers['Domain'].value_counts())
# Out:
# Domain
# hart.com               14
# buck.com               10
# hanson.com             10
# castro.com             10
# gross.com              10
#                        ..
# farley.info             1
# gordon-bradley.com      1
# ortiz-hendricks.com     1
# reid-sutton.com         1
# villegas-wilcox.com     1
# Name: count, Length: 6270, dtype: int64

# %%
customers[(customers['updated_year']=='2020') & (customers['Country']=='Norway')]
# Out:
# Empty DataFrame
# Columns: [Index, Customer Id, First Name, Last Name, Company, City, Country, Phone 1, Phone 2, Email, Subscription Date, Website, Year, Domain, updated_year]
# Index: []

# %%
customers
# Out:
#       Index      Customer Id First Name   Last Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather    Callahan              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina     Ferrell  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana    Andersen               Irwin-Oneal
# 3         4  6d350C5E5eDB4EE      Patty       Ponce          Richardson Group
# 4         5  5820deAdCF23EFe   Kathleen   Mccormick              Carson-Burch
# ...     ...              ...        ...         ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan       Cline            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery              Burns-Holden
#
# ...

# %%
customers['sorted_phone_no']= customers['Phone 1'].str.replace('.','-',regex=False)

# %%
customers.head(50)
# Out:
#     Index      Customer Id First Name   Last Name  \
# 0       1  EB54EF1154C3A78    Heather    Callahan
# 1       2  10dAcafEBbA5FcA   Kristina     Ferrell
# 2       3  67DAB15Ebe4BE4a     Briana    Andersen
# 3       4  6d350C5E5eDB4EE      Patty       Ponce
# 4       5  5820deAdCF23EFe   Kathleen   Mccormick
# 5       6  E1CDEaC63fDd5aA     Trevor         Lee
# 6       7  3e1187fCcebC8d2     Mathew     Hoffman
# 7       8  47C5cEE243c9A7b      Glenn     Wiggins
# 8       9  cacaD68a5e4BF4b      Bruce       Payne
# 9      10  436b9c41cfb1fa3    Brendan      Franco
# 10     11  9653ca648e2E414     Martin     Hawkins
# 11     12  e586A2D67bcdB48       Sara     Shaffer
# 12     13  c388ECa44FFe37c       Dave       Moran
# 13     14  f8dddbf9CD6FF92       Glen     Hammond
# 14     15  86Df56BFCc0a7CA  Catherine   Blackwell
# 15     16  2cfDE68A372cC7A      Larry      Newton
# 16     17  14CBc0BDfbE6FEA      Danny      Archer
# 17     18  48b3ACBfD6A5cdC        Kim     Griffin
# ...
